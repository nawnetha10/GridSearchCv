# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
#determine the columns with missing values
df[df['BloodPressure'] == 0].shape
# Out:
# (35, 9)

# %%
# preprocess the data
# remove the rows with missing values from relevent columns
columns = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for c in columns:
    df[c].replace(0, np.NaN, inplace=True)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  763.000000     733.000000     541.000000  394.000000
# mean      3.845052  121.686763      72.405184      29.153420  155.548223
# std       3.369578   30.535641      12.382158      10.476982  118.775855
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      22.000000   76.250000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.300000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# drop the rows with NaN vlues
df.dropna(inplace=True)
df. describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   392.000000  392.000000     392.000000     392.000000  392.000000
# mean      3.301020  122.627551      70.663265      29.145408  156.056122
# std       3.211424   30.860781      12.496092      10.516424  118.841690
# min       0.000000   56.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      62.000000      21.000000   76.750000
# 50%       2.000000  119.000000      70.000000      29.000000  125.500000
# 75%       5.000000  143.000000      78.000000      37.000000  190.000000
# max      17.000000  198.000000     110.000000      63.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  392.000000                392.000000  392.000000  392.000000
# mean    33.086224                  0.523046   30.864796    0.331633
# std      7.027659                  0.345488   10.200777    0.471401
# min     18.200000                  0.085000   21.000000    0.000000
# 25%     28.400000                  0.269750   23.000000    0.000000
# 50%     33.200000                  0.449500   27.000000    0.000000
# 75%     37.100000                  0.687000   36.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# convert the data to numpy array
data = df.values
print(data.shape)
# Out:
# (392, 9)

# %%
# extract the input and lebels 
x = data[:, 0:-1]
y = data[:, -1].astype(int)
print(x.shape)
print(y.shape)
# Out:
# (392, 8)
# (392,)

# %%
# normalize and standardize the data
from sklearn.preprocessing import StandardScaler

stand = StandardScaler().fit(x)
standardizedData = stand.transform(x)

data = pd.DataFrame(standardizedData) 
data.describe()
# Out:
#                   0             1             2             3             4  \
# count  3.920000e+02  3.920000e+02  3.920000e+02  3.920000e+02  3.920000e+02
# mean  -4.021726e-17  3.129583e-17 -4.641624e-16  1.042250e-16  6.485742e-17
# std    1.001278e+00  1.001278e+00  1.001278e+00  1.001278e+00  1.001278e+00
# min   -1.029213e+00 -2.161731e+00 -3.739001e+00 -2.108484e+00 -1.196867e+00
# 25%   -7.174265e-01 -7.665958e-01 -6.941640e-01 -7.755315e-01 -6.681786e-01
# 50%   -4.056403e-01 -1.176959e-01 -5.314565e-02 -1.384444e-02 -2.574448e-01
# 75%    5.297185e-01  6.609841e-01  5.878727e-01  7.478426e-01  2.859877e-01
# max    4.271153e+00  2.445459e+00  3.151946e+00  3.223325e+00  5.812990e+00
#
#                   5             6             7
# count  3.920000e+02  3.920000e+02  3.920000e+02
# mean   1.543550e-16  1.897575e-17  1.028089e-16
# std    1.001278e+00  1.001278e+00  1.001278e+00
# min   -2.120941e+00 -1.269525e+00 -9.682991e-01
# 25%   -6.676780e-01 -7.340909e-01 -7.719850e-01
# 50%    1.621036e-02 -2.131475e-01 -3.793569e-01
# 75%    5.718696e-01  4.751644e-01  5.040564e-01
# max    4.846172e+00  5.497667e+00  4.921123e+00

# %% [markdown]
# <h3>Optimizer Grid Search</h3>

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import numpy
def create_model(optimizer='Nadam', init='uniform', activation='relu'):
	# create model
	model = Sequential()  
	model.add(Dense(12, input_dim=8, kernel_initializer=init, activation=activation))
	model.add(Dropout(0.2))
    
	model.add(Dense(8, kernel_initializer=init, activation=activation))
	model.add(Dropout(0.2))
    
	# final layer (binary)
	model.add(Dense(1, kernel_initializer=init, activation='sigmoid'))
    
	# Compile model
	model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
	return model
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# load pima indians dataset
dataset = numpy.loadtxt("diabetes.csv", delimiter="," ,skiprows=1)

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# create model
model = KerasClassifier(build_fn=create_model, verbose=0)

# grid search epochs, batch size and optimizer ('TFOptimizer' throws error)
optimizers = ['SGD','RMSprop','Adagrad','Adadelta','Adam','Adamax','Nadam']
activations = ['softmax','softplus','softsign','relu','tanh','sigmoid','hard_sigmoid','linear']

# 'glorot_uniform', 'normal', 'uniform'
# init = ['uniform','lecun_uniform','normal','identity','orthogonal','zero','one','glorot_normal','glorot_uniform', 'he_normal', 'he_uniform']
# init = ['uniform','lecun_uniform','normal','orthogonal','zero','one','glorot_normal','glorot_uniform', 'he_normal', 'he_uniform']
init = ['normal']
        
# just one epoch to save computational time (300 is optimum for this 12,8,1 model)
epochs = [50]
# batches can be 1,3,5,10,20,40
batches = [5]

param_grid = dict(optimizer=optimizers, nb_epoch=epochs, batch_size=batches, init=init, activation=activations)
grid = GridSearchCV(cv=3, estimator=model, param_grid=param_grid, n_jobs=-1)
grid_result = grid.fit(X, Y)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_11400/4169190933.py:33: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=create_model, verbose=0)
# Best: 0.661458 using {'activation': 'relu', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'SGD'}
# 0.651042 (0.024774) with: {'activation': 'softmax', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'SGD'}
# 0.651042 (0.024774) with: {'activation': 'softmax', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'RMSprop'}
# 0.651042 (0.024774) with: {'activation': 'softmax', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adagrad'}
# 0.455729 (0.146518) with: {'activation': 'softmax', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adadelta'}
# 0.651042 (0.024774) with: {'activation': 'softmax', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adam'}
# 0.651042 (0.024774) with: {'activation': 'softmax', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adamax'}
# 0.651042 (0.024774) with: {'activation': 'softmax', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Nadam'}
# 0.651042 (0.024774) with: {'activation': 'softplus', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'SGD'}
# 0.651042 (0.024774) with: {'activation': 'softplus', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'RMSprop'}
# 0.427083 (0.134575) with: {'activation': 'softplus', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adagrad'}
# 0.460938 (0.141957) with: {'activation': 'softplus', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adadelta'}
# 0.651042 (0.024774) with: {'activation': 'softplus', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adam'}
# 0.654948 (0.028940) with: {'activation': 'softplus', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adamax'}
# 0.651042 (0.024774) with: {'activation': 'softplus', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Nadam'}
# 0.651042 (0.024774) with: {'activation': 'softsign', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'SGD'}
# 0.651042 (0.024774) with: {'activation': 'softsign', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'RMSprop'}
# 0.653646 (0.015733) with: {'activation': 'softsign', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adagrad'}
# 0.471354 (0.118754) with: {'activation': 'softsign', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adadelta'}
# 0.651042 (0.024774) with: {'activation': 'softsign', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adam'}
# 0.651042 (0.024774) with: {'activation': 'softsign', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adamax'}
# 0.651042 (0.024774) with: {'activation': 'softsign', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Nadam'}
# 0.661458 (0.017566) with: {'activation': 'relu', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'SGD'}
# 0.651042 (0.024774) with: {'activation': 'relu', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'RMSprop'}
# 0.545573 (0.131749) with: {'activation': 'relu', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adagrad'}
# 0.587240 (0.062690) with: {'activation': 'relu', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adadelta'}
# 0.651042 (0.024774) with: {'activation': 'relu', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adam'}
# 0.619792 (0.043303) with: {'activation': 'relu', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adamax'}
# 0.651042 (0.024774) with: {'activation': 'relu', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Nadam'}
# 0.651042 (0.024774) with: {'activation': 'tanh', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'SGD'}
# 0.651042 (0.024774) with: {'activation': 'tanh', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'RMSprop'}
# 0.649740 (0.024360) with: {'activation': 'tanh', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adagrad'}
# 0.529948 (0.115188) with: {'activation': 'tanh', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adadelta'}
# 0.651042 (0.024774) with: {'activation': 'tanh', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adam'}
# 0.651042 (0.024774) with: {'activation': 'tanh', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adamax'}
# 0.651042 (0.024774) with: {'activation': 'tanh', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Nadam'}
# 0.651042 (0.024774) with: {'activation': 'sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'SGD'}
# 0.651042 (0.024774) with: {'activation': 'sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'RMSprop'}
# 0.651042 (0.024774) with: {'activation': 'sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adagrad'}
# 0.572917 (0.134575) with: {'activation': 'sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adadelta'}
# 0.651042 (0.024774) with: {'activation': 'sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adam'}
# 0.651042 (0.024774) with: {'activation': 'sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adamax'}
# 0.651042 (0.024774) with: {'activation': 'sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Nadam'}
# 0.651042 (0.024774) with: {'activation': 'hard_sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'SGD'}
# 0.651042 (0.024774) with: {'activation': 'hard_sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'RMSprop'}
# 0.544271 (0.146518) with: {'activation': 'hard_sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adagrad'}
# 0.348958 (0.024774) with: {'activation': 'hard_sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adadelta'}
# 0.651042 (0.024774) with: {'activation': 'hard_sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adam'}
# 0.651042 (0.024774) with: {'activation': 'hard_sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adamax'}
# 0.651042 (0.024774) with: {'activation': 'hard_sigmoid', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Nadam'}
# 0.652344 (0.022999) with: {'activation': 'linear', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'SGD'}
# 0.651042 (0.024774) with: {'activation': 'linear', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'RMSprop'}
# 0.545573 (0.144701) with: {'activation': 'linear', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adagrad'}
# 0.631510 (0.031948) with: {'activation': 'linear', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adadelta'}
# 0.653646 (0.027498) with: {'activation': 'linear', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adam'}
# 0.648438 (0.024080) with: {'activation': 'linear', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Adamax'}
# 0.653646 (0.026557) with: {'activation': 'linear', 'batch_size': 5, 'init': 'normal', 'nb_epoch': 50, 'optimizer': 'Nadam'}

# %% [markdown]
# <h3> tuning the batch size and number of epochs </h3>

# %%
import numpy
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
# Function to create model, required for KerasClassifier
def create_model():
	# create model
	model = Sequential()
	model.add(Dense(12, input_dim=8, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# Compile model
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load dataset
dataset = numpy.loadtxt("diabetes.csv", delimiter=",",skiprows=1)
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = KerasClassifier(build_fn=create_model, verbose=0)
# define the grid search parameters
batch_size = [10, 20, 40, 60, 80, 100]
epochs = [10, 50, 100]
param_grid = dict(batch_size=batch_size, epochs=epochs)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_11400/464534832.py:24: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=create_model, verbose=0)
# Best: 0.716146 using {'batch_size': 10, 'epochs': 100}
# 0.593750 (0.016573) with: {'batch_size': 10, 'epochs': 10}
# 0.630208 (0.020752) with: {'batch_size': 10, 'epochs': 50}
# 0.716146 (0.035564) with: {'batch_size': 10, 'epochs': 100}
# 0.595052 (0.049032) with: {'batch_size': 20, 'epochs': 10}
# 0.648438 (0.014616) with: {'batch_size': 20, 'epochs': 50}
# 0.704427 (0.010253) with: {'batch_size': 20, 'epochs': 100}
# 0.554688 (0.068998) with: {'batch_size': 40, 'epochs': 10}
# 0.669271 (0.039623) with: {'batch_size': 40, 'epochs': 50}
# 0.657552 (0.018136) with: {'batch_size': 40, 'epochs': 100}
# 0.595052 (0.044690) with: {'batch_size': 60, 'epochs': 10}
# 0.617188 (0.080498) with: {'batch_size': 60, 'epochs': 50}
# 0.654948 (0.014731) with: {'batch_size': 60, 'epochs': 100}
# 0.557292 (0.043537) with: {'batch_size': 80, 'epochs': 10}
# 0.649740 (0.017566) with: {'batch_size': 80, 'epochs': 50}
# 0.680990 (0.004872) with: {'batch_size': 80, 'epochs': 100}
# 0.615885 (0.037240) with: {'batch_size': 100, 'epochs': 10}
# 0.598958 (0.024360) with: {'batch_size': 100, 'epochs': 50}
# 0.662760 (0.032106) with: {'batch_size': 100, 'epochs': 100}

# %% [markdown]
# <H3>Tune the Training Optimization Algorithm</H3>
#  we tune the optimization algorithm used to train the network, each with default parameters.

# %%
import numpy
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
# Function to create model, required for KerasClassifier
def create_model(optimizer='adam'):
	# create model
	model = Sequential()
	model.add(Dense(12, input_dim=8, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# Compile model
	model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
	return model
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load dataset
dataset = numpy.loadtxt("diabetes.csv", delimiter=",",skiprows=1)
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = KerasClassifier(build_fn=create_model, epochs=100, batch_size=10, verbose=0)
# define the grid search parameters
optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
param_grid = dict(optimizer=optimizer)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_11400/3473220031.py:24: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=create_model, epochs=100, batch_size=10, verbose=0)
# Best: 0.709635 using {'optimizer': 'Nadam'}
# 0.657552 (0.031948) with: {'optimizer': 'SGD'}
# 0.567708 (0.119352) with: {'optimizer': 'RMSprop'}
# 0.541667 (0.037377) with: {'optimizer': 'Adagrad'}
# 0.516927 (0.128465) with: {'optimizer': 'Adadelta'}
# 0.697917 (0.023073) with: {'optimizer': 'Adam'}
# 0.643229 (0.007366) with: {'optimizer': 'Adamax'}
# 0.709635 (0.010253) with: {'optimizer': 'Nadam'}

# %% [markdown]
# <H3>Tune Network Weight Initialization</H3>
# Neural network weight initialization used to be simple: use small random values.

# %%
import numpy
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
# Function to create model, required for KerasClassifier
def create_model(init_mode='uniform'):
	# create model
	model = Sequential()
	model.add(Dense(12, input_dim=8, kernel_initializer=init_mode, activation='relu'))
	model.add(Dense(1, kernel_initializer=init_mode, activation='sigmoid'))
	# Compile model
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load dataset
dataset = numpy.loadtxt("diabetes.csv", delimiter=",",skiprows=1)
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = KerasClassifier(build_fn=create_model, epochs=100, batch_size=10, verbose=0)
# define the grid search parameters
init_mode = ['uniform', 'lecun_uniform', 'normal', 'zero', 'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform']
param_grid = dict(init_mode=init_mode)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_11400/791556369.py:24: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=create_model, epochs=100, batch_size=10, verbose=0)
# Best: 0.722656 using {'init_mode': 'normal'}
# 0.708333 (0.014731) with: {'init_mode': 'uniform'}
# 0.700521 (0.021236) with: {'init_mode': 'lecun_uniform'}
# 0.722656 (0.014616) with: {'init_mode': 'normal'}
# 0.651042 (0.024774) with: {'init_mode': 'zero'}
# 0.692708 (0.019225) with: {'init_mode': 'glorot_normal'}
# 0.683594 (0.049513) with: {'init_mode': 'glorot_uniform'}
# 0.707031 (0.022326) with: {'init_mode': 'he_normal'}
# 0.709635 (0.023939) with: {'init_mode': 'he_uniform'}

# %% [markdown]
# <H4>CONCLUSION: To find Best hyperparameter optimization</H4>
#   <h4>k-fold Cross Validation:A default cross-validation of 3 was used, but perhaps k=5 or k=10 would be more stable</h4>
#  <h4>Use a Sample of Your Dataset. Because networks are slow to train, try training them on a smaller sample of your training dataset, just to get an idea of general directions of parameters rather than optimal configurations.</h4>
